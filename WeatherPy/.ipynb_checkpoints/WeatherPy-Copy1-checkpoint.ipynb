# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\carol\anaconda3\envs\bootcamp3\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in c:\users\carol\anaconda3\envs\bootcamp3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
#Test API is reading weather data - Tues 01-Lesson-Plans>06-Python-APIs>2>Activities>07-Stu_Weather_Stats

# Save config information.
#url = "http://api.openweathermap.org/data/2.5/weather?"
#units = "metric"
#query_url = f"{url}appid={weather_api_key}&units={units}&q="

# List of cities
#cities = []

# set up lists to hold reponse info
#lon = []
#temp = []

# Loop through the list of cities and perform a request for data on each
#for city in cities:
   # response = requests.get(query_url + city).json()
  #  lon.append(response['coord']['lon'])
  #  temp.append(response['main']['temp'])

#print(f"The longitude information received is: {lon}")
#print(f"The temperature information received is: {temp}")
# Out:
# The longitude information received is: [2.3488, -0.1257, -68.5364, 141.2906, 111.9767, 153.5833, 125.2833, -35.4608, -52.7093, -68.3]
# The temperature information received is: [22.05, 17.73, 12.79, 25.47, 24.6, 18.78, 32.15, 24.05, 15.86, 3.81]

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
#print(cities)
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grytviken
# Processing Record 2 of Set 1 | svetlograd
# Processing Record 3 of Set 1 | prado
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | fort mcmurray
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | waitangi
# Processing Record 9 of Set 1 | edinburgh of the seven seas
# Processing Record 10 of Set 1 | labytnangi
# Processing Record 11 of Set 1 | fort bragg
# Processing Record 12 of Set 1 | isafjordur
# Processing Record 13 of Set 1 | polyarnyy
# Processing Record 14 of Set 1 | peniche
# Processing Record 15 of Set 1 | olonkinbyen
# Processing Record 16 of Set 1 | colonia menno
# Processing Record 17 of Set 1 | lihue
# Processing Record 18 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 19 of Set 1 | invercargill
# Processing Record 20 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 21 of Set 1 | port lincoln
# Processing Record 22 of Set 1 | cluain meala
# Processing Record 23 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | port-aux-francais
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | qaqortoq
# Processing Record 29 of Set 1 | hamilton
# Processing Record 30 of Set 1 | fale old settlement
# Processing Record 31 of Set 1 | yamada
# Processing Record 32 of Set 1 | basco
# Processing Record 33 of Set 1 | grand rapids
# Processing Record 34 of Set 1 | boguchany
# Processing Record 35 of Set 1 | port mathurin
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | puerto natales
# Processing Record 38 of Set 1 | keflavik
# Processing Record 39 of Set 1 | ciudad constitucion
# Processing Record 40 of Set 1 | klyuchi
# Processing Record 41 of Set 1 | nemuro
# Processing Record 42 of Set 1 | anadyr
# Processing Record 43 of Set 1 | la passe
# Processing Record 44 of Set 1 | college
# Processing Record 45 of Set 1 | wailua homesteads
# Processing Record 46 of Set 1 | egilsstadir
# Processing Record 47 of Set 1 | nizhniy kuranakh
# Processing Record 48 of Set 1 | tofol
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 0 of Set 2 | enewetak
# Processing Record 1 of Set 2 | olavarria
# Processing Record 2 of Set 2 | viedma
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | blackmans bay
# Processing Record 5 of Set 2 | west island
# Processing Record 6 of Set 2 | cidreira
# Processing Record 7 of Set 2 | de aar
# Processing Record 8 of Set 2 | hadibu
# Processing Record 9 of Set 2 | fortuna
# Processing Record 10 of Set 2 | swainsboro
# Processing Record 11 of Set 2 | nova sintra
# Processing Record 12 of Set 2 | vryburg
# Processing Record 13 of Set 2 | cabo san lucas
# Processing Record 14 of Set 2 | rach gia
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | whitehorse
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | ballymoney
# Processing Record 19 of Set 2 | bethel
# Processing Record 20 of Set 2 | ed damer
# Processing Record 21 of Set 2 | loncoche
# Processing Record 22 of Set 2 | kruisfontein
# Processing Record 23 of Set 2 | rongelap
# Processing Record 24 of Set 2 | margaret river
# Processing Record 25 of Set 2 | swift current
# Processing Record 26 of Set 2 | chonchi
# Processing Record 27 of Set 2 | reggane
# Processing Record 28 of Set 2 | chimore
# Processing Record 29 of Set 2 | shalqar
# Processing Record 30 of Set 2 | hotan
# Processing Record 31 of Set 2 | punta arenas
# Processing Record 32 of Set 2 | poli
# Processing Record 33 of Set 2 | yasuj
# Processing Record 34 of Set 2 | bilibino
# Processing Record 35 of Set 2 | iskateley
# Processing Record 36 of Set 2 | sabang
# Processing Record 37 of Set 2 | safaga
# Processing Record 38 of Set 2 | hailar
# Processing Record 39 of Set 2 | margate
# Processing Record 40 of Set 2 | armacao de buzios
# Processing Record 41 of Set 2 | viqueque
# Processing Record 42 of Set 2 | usogorsk
# Processing Record 43 of Set 2 | addiet canna
# Processing Record 44 of Set 2 | touros
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | annau
# Processing Record 47 of Set 2 | tamala
# Processing Record 48 of Set 2 | new ulm
# Processing Record 49 of Set 2 | dainava (kaunas)
# Processing Record 0 of Set 3 | belomorsk
# Processing Record 1 of Set 3 | brisas de zicatela
# Processing Record 2 of Set 3 | sungailiat
# Processing Record 3 of Set 3 | rio preto da eva
# Processing Record 4 of Set 3 | makokou
# Processing Record 5 of Set 3 | montepuez
# Processing Record 6 of Set 3 | dali
# Processing Record 7 of Set 3 | dolores
# Processing Record 8 of Set 3 | colonia
# Processing Record 9 of Set 3 | sosnovo-ozerskoye
# Processing Record 10 of Set 3 | quva
# Processing Record 11 of Set 3 | ivanteyevka
# Processing Record 12 of Set 3 | kudahuvadhoo
# Processing Record 13 of Set 3 | kimbe
# Processing Record 14 of Set 3 | piti village
# Processing Record 15 of Set 3 | pimentel
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | ushuaia
# Processing Record 18 of Set 3 | matthew town
# Processing Record 19 of Set 3 | igarka
# Processing Record 20 of Set 3 | shenjiamen
# Processing Record 21 of Set 3 | tura
# Processing Record 22 of Set 3 | castillos
# Processing Record 23 of Set 3 | bredasdorp
# Processing Record 24 of Set 3 | princeville
# Processing Record 25 of Set 3 | saudarkrokur
# Processing Record 26 of Set 3 | constantia
# Processing Record 27 of Set 3 | yagry
# City not found. Skipping...
# Processing Record 28 of Set 3 | kingaroy
# Processing Record 29 of Set 3 | dondo
# Processing Record 30 of Set 3 | namibe
# Processing Record 31 of Set 3 | dhuusamarreeb
# Processing Record 32 of Set 3 | thompson
# Processing Record 33 of Set 3 | nuuk
# Processing Record 34 of Set 3 | vorkuta
# Processing Record 35 of Set 3 | mboursou lere
# Processing Record 36 of Set 3 | quellon
# Processing Record 37 of Set 3 | ponta delgada
# Processing Record 38 of Set 3 | kununurra
# Processing Record 39 of Set 3 | taltal
# Processing Record 40 of Set 3 | nagqu
# Processing Record 41 of Set 3 | portland
# Processing Record 42 of Set 3 | bargara
# City not found. Skipping...
# Processing Record 43 of Set 3 | newman
# Processing Record 44 of Set 3 | sao jose da coroa grande
# Processing Record 45 of Set 3 | taiynsha
# Processing Record 46 of Set 3 | saldanha
# Processing Record 47 of Set 3 | utrik
# Processing Record 48 of Set 3 | kavaratti
# Processing Record 49 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 0 of Set 4 | khandyga
# Processing Record 1 of Set 4 | berezovo
# Processing Record 2 of Set 4 | bulgan
# Processing Record 3 of Set 4 | jayapura
# Processing Record 4 of Set 4 | yoichi
# Processing Record 5 of Set 4 | murrells inlet
# Processing Record 6 of Set 4 | nevada
# Processing Record 7 of Set 4 | warrnambool
# Processing Record 8 of Set 4 | ust-nera
# Processing Record 9 of Set 4 | isangel
# Processing Record 10 of Set 4 | si sa ket
# Processing Record 11 of Set 4 | hampton bays
# Processing Record 12 of Set 4 | prince rupert
# Processing Record 13 of Set 4 | brookings
# Processing Record 14 of Set 4 | stanley
# Processing Record 15 of Set 4 | elliot lake
# Processing Record 16 of Set 4 | hermanus
# Processing Record 17 of Set 4 | hobyo
# Processing Record 18 of Set 4 | puerto madero
# Processing Record 19 of Set 4 | zhaotong
# Processing Record 20 of Set 4 | pemangkat
# Processing Record 21 of Set 4 | guadalupe y calvo
# Processing Record 22 of Set 4 | chipinge
# Processing Record 23 of Set 4 | trujillo
# Processing Record 24 of Set 4 | zhongshu
# Processing Record 25 of Set 4 | luchegorsk
# Processing Record 26 of Set 4 | pangoa
# Processing Record 27 of Set 4 | salym
# Processing Record 28 of Set 4 | yulinshi
# Processing Record 29 of Set 4 | vadso
# Processing Record 30 of Set 4 | curup
# Processing Record 31 of Set 4 | presidente epitacio
# Processing Record 32 of Set 4 | opuwo
# Processing Record 33 of Set 4 | cooper's town
# Processing Record 34 of Set 4 | flying fish cove
# Processing Record 35 of Set 4 | leua
# Processing Record 36 of Set 4 | udachny
# Processing Record 37 of Set 4 | hami
# Processing Record 38 of Set 4 | guerrero negro
# Processing Record 39 of Set 4 | rundu
# Processing Record 40 of Set 4 | mitu
# Processing Record 41 of Set 4 | elko
# Processing Record 42 of Set 4 | baoqing
# Processing Record 43 of Set 4 | oxapampa
# Processing Record 44 of Set 4 | hoxtolgay
# City not found. Skipping...
# Processing Record 45 of Set 4 | san antonio de pale
# Processing Record 46 of Set 4 | nicoya
# Processing Record 47 of Set 4 | gubkinskiy
# Processing Record 48 of Set 4 | bubaque
# Processing Record 49 of Set 4 | thal
# Processing Record 0 of Set 5 | arkhangel'sk
# Processing Record 1 of Set 5 | kovalam
# Processing Record 2 of Set 5 | kapa'a
# Processing Record 3 of Set 5 | sparti
# Processing Record 4 of Set 5 | ulladulla
# Processing Record 5 of Set 5 | rimouski
# Processing Record 6 of Set 5 | lebu
# Processing Record 7 of Set 5 | tolanaro
# Processing Record 8 of Set 5 | tsiombe
# Processing Record 9 of Set 5 | tokonou
# Processing Record 10 of Set 5 | callao
# Processing Record 11 of Set 5 | mendi
# Processing Record 12 of Set 5 | yarovoye
# Processing Record 13 of Set 5 | burgersdorp
# Processing Record 14 of Set 5 | ancud
# Processing Record 15 of Set 5 | kuanda
# Processing Record 16 of Set 5 | antofagasta
# Processing Record 17 of Set 5 | suva
# Processing Record 18 of Set 5 | vilyuchinsk
# Processing Record 19 of Set 5 | praia da vitoria
# Processing Record 20 of Set 5 | iranshahr
# Processing Record 21 of Set 5 | hawaiian paradise park
# Processing Record 22 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 23 of Set 5 | champerico
# Processing Record 24 of Set 5 | san patricio
# Processing Record 25 of Set 5 | east london
# Processing Record 26 of Set 5 | richards bay
# Processing Record 27 of Set 5 | axim
# Processing Record 28 of Set 5 | ilulissat
# Processing Record 29 of Set 5 | derzhavinsk
# Processing Record 30 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 5 | mejit
# Processing Record 32 of Set 5 | vorgashor
# Processing Record 33 of Set 5 | taco pozo
# Processing Record 34 of Set 5 | fort st. john
# Processing Record 35 of Set 5 | aripuana
# Processing Record 36 of Set 5 | nizhneangarsk
# Processing Record 37 of Set 5 | gombong
# Processing Record 38 of Set 5 | jiazi
# Processing Record 39 of Set 5 | chibougamau
# Processing Record 40 of Set 5 | rio grande
# Processing Record 41 of Set 5 | graaff-reinet
# Processing Record 42 of Set 5 | bandarbeyla
# Processing Record 43 of Set 5 | chania
# Processing Record 44 of Set 5 | leh
# Processing Record 45 of Set 5 | altai
# Processing Record 46 of Set 5 | porto novo
# Processing Record 47 of Set 5 | zeya
# Processing Record 48 of Set 5 | gebre guracha
# Processing Record 49 of Set 5 | mao
# Processing Record 0 of Set 6 | kone
# Processing Record 1 of Set 6 | haiku-pauwela
# Processing Record 2 of Set 6 | holualoa
# Processing Record 3 of Set 6 | lagoa formosa
# Processing Record 4 of Set 6 | hinton
# Processing Record 5 of Set 6 | tual
# Processing Record 6 of Set 6 | kirakira
# Processing Record 7 of Set 6 | port alfred
# Processing Record 8 of Set 6 | laojunmiao
# Processing Record 9 of Set 6 | tralee
# Processing Record 10 of Set 6 | cotonou
# Processing Record 11 of Set 6 | port douglas
# Processing Record 12 of Set 6 | xilin hot
# Processing Record 13 of Set 6 | la gomera
# Processing Record 14 of Set 6 | arraial do cabo
# Processing Record 15 of Set 6 | sunzha
# Processing Record 16 of Set 6 | badger
# Processing Record 17 of Set 6 | medicine hat
# Processing Record 18 of Set 6 | lompoc
# Processing Record 19 of Set 6 | bridgewater
# Processing Record 20 of Set 6 | nar'yan-mar
# Processing Record 21 of Set 6 | uturoa
# Processing Record 22 of Set 6 | sangin
# Processing Record 23 of Set 6 | dwarka
# Processing Record 24 of Set 6 | kayangel
# Processing Record 25 of Set 6 | forster
# Processing Record 26 of Set 6 | mount isa
# Processing Record 27 of Set 6 | chapayevsk
# Processing Record 28 of Set 6 | badagara
# Processing Record 29 of Set 6 | port elizabeth
# Processing Record 30 of Set 6 | pacific grove
# Processing Record 31 of Set 6 | pontes e lacerda
# Processing Record 32 of Set 6 | gambiran satu
# Processing Record 33 of Set 6 | lensk
# Processing Record 34 of Set 6 | talnakh
# Processing Record 35 of Set 6 | hammerfest
# Processing Record 36 of Set 6 | jiagedaqi
# Processing Record 37 of Set 6 | wenchang
# Processing Record 38 of Set 6 | at taj
# Processing Record 39 of Set 6 | nouadhibou
# Processing Record 40 of Set 6 | sao felix do xingu
# Processing Record 41 of Set 6 | yarmouth
# Processing Record 42 of Set 6 | acarau
# Processing Record 43 of Set 6 | kibaya
# Processing Record 44 of Set 6 | piacabucu
# Processing Record 45 of Set 6 | lagoa
# Processing Record 46 of Set 6 | twon-brass
# Processing Record 47 of Set 6 | bria
# Processing Record 48 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 49 of Set 6 | bich'vinta
# Processing Record 0 of Set 7 | zanjan
# Processing Record 1 of Set 7 | cable beach
# City not found. Skipping...
# Processing Record 2 of Set 7 | thetford-mines
# Processing Record 3 of Set 7 | kargopol'
# Processing Record 4 of Set 7 | tazovsky
# Processing Record 5 of Set 7 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 6 of Set 7 | gadzhiyevo
# Processing Record 7 of Set 7 | la sarre
# Processing Record 8 of Set 7 | lubao
# Processing Record 9 of Set 7 | ilha de mocambique
# Processing Record 10 of Set 7 | san sebastian de la gomera
# Processing Record 11 of Set 7 | alofi
# Processing Record 12 of Set 7 | afaahiti
# Processing Record 13 of Set 7 | ketchikan
# Processing Record 14 of Set 7 | fort irwin
# Processing Record 15 of Set 7 | ursulo galvan
# Processing Record 16 of Set 7 | likiep
# Processing Record 17 of Set 7 | severo-yeniseyskiy
# Processing Record 18 of Set 7 | tago
# Processing Record 19 of Set 7 | lazaro cardenas
# Processing Record 20 of Set 7 | katsuura
# Processing Record 21 of Set 7 | aykhal
# Processing Record 22 of Set 7 | al jawf
# Processing Record 23 of Set 7 | pangai
# Processing Record 24 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 25 of Set 7 | aldan
# Processing Record 26 of Set 7 | kavieng
# Processing Record 27 of Set 7 | sisimiut
# Processing Record 28 of Set 7 | zuwarah
# Processing Record 29 of Set 7 | lumphat
# Processing Record 30 of Set 7 | mount pearl
# Processing Record 31 of Set 7 | kaharlyk
# Processing Record 32 of Set 7 | merizo village
# Processing Record 33 of Set 7 | fernie
# Processing Record 34 of Set 7 | al hazm
# Processing Record 35 of Set 7 | faya-largeau
# Processing Record 36 of Set 7 | huarmey
# Processing Record 37 of Set 7 | bongor
# Processing Record 38 of Set 7 | mirnyy
# Processing Record 39 of Set 7 | uthal
# Processing Record 40 of Set 7 | calingasta
# Processing Record 41 of Set 7 | papatowai
# Processing Record 42 of Set 7 | akureyri
# Processing Record 43 of Set 7 | black river
# Processing Record 44 of Set 7 | manadhoo
# Processing Record 45 of Set 7 | culpeper
# Processing Record 46 of Set 7 | santa rosa del sara
# City not found. Skipping...
# Processing Record 47 of Set 7 | tangalle
# Processing Record 48 of Set 7 | queenstown
# Processing Record 49 of Set 7 | colorado
# Processing Record 0 of Set 8 | hilo
# Processing Record 1 of Set 8 | glazov
# Processing Record 2 of Set 8 | jinghong
# Processing Record 3 of Set 8 | tafuna
# Processing Record 4 of Set 8 | nelson bay
# Processing Record 5 of Set 8 | kawthoung
# City not found. Skipping...
# Processing Record 6 of Set 8 | dhaka
# Processing Record 7 of Set 8 | al muwayh
# Processing Record 8 of Set 8 | juigalpa
# Processing Record 9 of Set 8 | tarrafal de sao nicolau
# Processing Record 10 of Set 8 | yeniseysk
# Processing Record 11 of Set 8 | mangrol
# Processing Record 12 of Set 8 | al mawsil al jadidah
# Processing Record 13 of Set 8 | hard bargain
# Processing Record 14 of Set 8 | marsh harbour
# Processing Record 15 of Set 8 | naze
# Processing Record 16 of Set 8 | pingliang
# Processing Record 17 of Set 8 | rabo de peixe
# Processing Record 18 of Set 8 | al kharijah
# Processing Record 19 of Set 8 | schonkirchen
# Processing Record 20 of Set 8 | botou
# Processing Record 21 of Set 8 | khamis mushait
# Processing Record 22 of Set 8 | mazagao
# Processing Record 23 of Set 8 | st. john's
# Processing Record 24 of Set 8 | esmeralda
# Processing Record 25 of Set 8 | aasiaat
# Processing Record 26 of Set 8 | kitgum
# Processing Record 27 of Set 8 | verkhovazh'ye
# Processing Record 28 of Set 8 | lafiagi
# Processing Record 29 of Set 8 | bhamo
# Processing Record 30 of Set 8 | vernal
# Processing Record 31 of Set 8 | dalandzadgad
# Processing Record 32 of Set 8 | tarawa
# Processing Record 33 of Set 8 | la ronge
# Processing Record 34 of Set 8 | chakradharpur
# Processing Record 35 of Set 8 | coihueco
# Processing Record 36 of Set 8 | puro
# Processing Record 37 of Set 8 | valparaiso
# Processing Record 38 of Set 8 | aden
# Processing Record 39 of Set 8 | nueva villa de padilla
# Processing Record 40 of Set 8 | slavonski brod
# Processing Record 41 of Set 8 | amahai
# Processing Record 42 of Set 8 | greenville
# Processing Record 43 of Set 8 | hasaki
# Processing Record 44 of Set 8 | general acha
# Processing Record 45 of Set 8 | port shepstone
# Processing Record 46 of Set 8 | ixtapa
# Processing Record 47 of Set 8 | mont-joli
# Processing Record 48 of Set 8 | new norfolk
# Processing Record 49 of Set 8 | metlili chaamba
# Processing Record 0 of Set 9 | homer
# Processing Record 1 of Set 9 | rikaze
# Processing Record 2 of Set 9 | kupang
# Processing Record 3 of Set 9 | mokhsogollokh
# Processing Record 4 of Set 9 | pitkyaranta
# Processing Record 5 of Set 9 | chulym
# Processing Record 6 of Set 9 | norderney
# Processing Record 7 of Set 9 | madalena
# Processing Record 8 of Set 9 | meadow lakes
# Processing Record 9 of Set 9 | port-vila
# Processing Record 10 of Set 9 | kashgar
# Processing Record 11 of Set 9 | trouville-sur-mer
# Processing Record 12 of Set 9 | kas
# Processing Record 13 of Set 9 | vila velha
# Processing Record 14 of Set 9 | caibarien
# Processing Record 15 of Set 9 | berdigestyakh
# Processing Record 16 of Set 9 | savelugu
# Processing Record 17 of Set 9 | luanda
# Processing Record 18 of Set 9 | nsanje
# Processing Record 19 of Set 9 | ternate
# Processing Record 20 of Set 9 | garachico
# Processing Record 21 of Set 9 | acapulco de juarez
# Processing Record 22 of Set 9 | laguna
# Processing Record 23 of Set 9 | shimoda
# Processing Record 24 of Set 9 | atafu village
# Processing Record 25 of Set 9 | kegums
# Processing Record 26 of Set 9 | dudinka
# Processing Record 27 of Set 9 | am djarass
# City not found. Skipping...
# Processing Record 28 of Set 9 | siniscola
# Processing Record 29 of Set 9 | wotho
# Processing Record 30 of Set 9 | el calafate
# Processing Record 31 of Set 9 | deqen
# Processing Record 32 of Set 9 | goz beida
# Processing Record 33 of Set 9 | luchow
# Processing Record 34 of Set 9 | kulia village
# City not found. Skipping...
# Processing Record 35 of Set 9 | sinabang
# Processing Record 36 of Set 9 | luena
# Processing Record 37 of Set 9 | shiraz
# Processing Record 38 of Set 9 | gaalkacyo
# Processing Record 39 of Set 9 | labuan
# Processing Record 40 of Set 9 | labis
# Processing Record 41 of Set 9 | wenling
# Processing Record 42 of Set 9 | koszalin
# Processing Record 43 of Set 9 | conceicao da barra
# Processing Record 44 of Set 9 | galle
# Processing Record 45 of Set 9 | rawai
# Processing Record 46 of Set 9 | khowy
# Processing Record 47 of Set 9 | northam
# Processing Record 48 of Set 9 | codrington
# Processing Record 49 of Set 9 | san andros
# City not found. Skipping...
# Processing Record 0 of Set 10 | gamboma
# Processing Record 1 of Set 10 | al bawiti
# Processing Record 2 of Set 10 | gizo
# Processing Record 3 of Set 10 | mokshan
# Processing Record 4 of Set 10 | keetmanshoop
# Processing Record 5 of Set 10 | raja
# Processing Record 6 of Set 10 | dunedin
# Processing Record 7 of Set 10 | happy valley-goose bay
# Processing Record 8 of Set 10 | ribas do rio pardo
# Processing Record 9 of Set 10 | cannonvale
# Processing Record 10 of Set 10 | tamanrasset
# Processing Record 11 of Set 10 | yelizovo
# Processing Record 12 of Set 10 | wellington
# Processing Record 13 of Set 10 | nueva gerona
# Processing Record 14 of Set 10 | sitka
# Processing Record 15 of Set 10 | concepcion del oro
# Processing Record 16 of Set 10 | maubara
# City not found. Skipping...
# Processing Record 17 of Set 10 | lepsy
# Processing Record 18 of Set 10 | andalgala
# Processing Record 19 of Set 10 | dul'durga
# Processing Record 20 of Set 10 | patos de minas
# Processing Record 21 of Set 10 | san luis de la loma
# Processing Record 22 of Set 10 | iquique
# Processing Record 23 of Set 10 | brosteni
# Processing Record 24 of Set 10 | ha'il
# Processing Record 25 of Set 10 | langsa
# Processing Record 26 of Set 10 | araguaina
# Processing Record 27 of Set 10 | bay roberts
# Processing Record 28 of Set 10 | jiuquan
# Processing Record 29 of Set 10 | dungarpur
# Processing Record 30 of Set 10 | qarauyl
# Processing Record 31 of Set 10 | alice springs
# Processing Record 32 of Set 10 | okha
# Processing Record 33 of Set 10 | sidney
# Processing Record 34 of Set 10 | porto murtinho
# Processing Record 35 of Set 10 | fonadhoo
# City not found. Skipping...
# Processing Record 36 of Set 10 | illela
# Processing Record 37 of Set 10 | katoomba
# Processing Record 38 of Set 10 | huazhou
# Processing Record 39 of Set 10 | gamba
# Processing Record 40 of Set 10 | mamuju
# Processing Record 41 of Set 10 | viechtach
# Processing Record 42 of Set 10 | yurimaguas
# Processing Record 43 of Set 10 | mil'kovo
# Processing Record 44 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 10 | vila franca do campo
# Processing Record 46 of Set 10 | zapala
# Processing Record 47 of Set 10 | laurel
# Processing Record 48 of Set 10 | bereznik
# Processing Record 49 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 0 of Set 11 | qamdo
# Processing Record 1 of Set 11 | black forest
# Processing Record 2 of Set 11 | neftcala
# Processing Record 3 of Set 11 | dakhla
# Processing Record 4 of Set 11 | rawson
# Processing Record 5 of Set 11 | tayshet
# Processing Record 6 of Set 11 | bucerias
# Processing Record 7 of Set 11 | brasileia
# Processing Record 8 of Set 11 | sandnessjoen
# Processing Record 9 of Set 11 | komarichi
# Processing Record 10 of Set 11 | caleta de carquin
# Processing Record 11 of Set 11 | tobi village
# City not found. Skipping...
# Processing Record 12 of Set 11 | tazacorte
# Processing Record 13 of Set 11 | motygino
# Processing Record 14 of Set 11 | tanout
# Processing Record 15 of Set 11 | calama
# Processing Record 16 of Set 11 | siwa oasis
# Processing Record 17 of Set 11 | malango
# Processing Record 18 of Set 11 | obudu
# Processing Record 19 of Set 11 | el estor
# Processing Record 20 of Set 11 | lata
# Processing Record 21 of Set 11 | genhe
# Processing Record 22 of Set 11 | ellsworth
# Processing Record 23 of Set 11 | obock
# Processing Record 24 of Set 11 | ipu
# Processing Record 25 of Set 11 | arar
# Processing Record 26 of Set 11 | kingsford
# Processing Record 27 of Set 11 | bulungu
# Processing Record 28 of Set 11 | nampula
# Processing Record 29 of Set 11 | meadow lake
# Processing Record 30 of Set 11 | hospet
# Processing Record 31 of Set 11 | sirte
# Processing Record 32 of Set 11 | mocimboa
# Processing Record 33 of Set 11 | altamira
# Processing Record 34 of Set 11 | tan-tan
# Processing Record 35 of Set 11 | taguatinga
# Processing Record 36 of Set 11 | papao
# Processing Record 37 of Set 11 | shingu
# Processing Record 38 of Set 11 | beau vallon
# Processing Record 39 of Set 11 | cabedelo
# Processing Record 40 of Set 11 | ishigaki
# Processing Record 41 of Set 11 | kerikeri
# Processing Record 42 of Set 11 | broken hill
# Processing Record 43 of Set 11 | mahina
# Processing Record 44 of Set 11 | santa elena
# Processing Record 45 of Set 11 | susuman
# Processing Record 46 of Set 11 | la mira
# Processing Record 47 of Set 11 | tyukhtet
# Processing Record 48 of Set 11 | kourou
# Processing Record 49 of Set 11 | ciudad cerralvo
# City not found. Skipping...
# Processing Record 0 of Set 12 | kachug
# Processing Record 1 of Set 12 | krasnyy chikoy
# Processing Record 2 of Set 12 | mahibadhoo
# Processing Record 3 of Set 12 | hastings
# Processing Record 4 of Set 12 | luderitz
# Processing Record 5 of Set 12 | mahabe
# City not found. Skipping...
# Processing Record 6 of Set 12 | saipan
# Processing Record 7 of Set 12 | keita
# Processing Record 8 of Set 12 | moss bluff
# Processing Record 9 of Set 12 | ostersund
# Processing Record 10 of Set 12 | kodinsk
# Processing Record 11 of Set 12 | usinsk
# Processing Record 12 of Set 12 | uyuni
# Processing Record 13 of Set 12 | salinopolis
# Processing Record 14 of Set 12 | ghormach
# Processing Record 15 of Set 12 | itarare
# Processing Record 16 of Set 12 | swanage
# Processing Record 17 of Set 12 | upington
# Processing Record 18 of Set 12 | dar naim
# City not found. Skipping...
# Processing Record 19 of Set 12 | shache
# Processing Record 20 of Set 12 | kitwe
# Processing Record 21 of Set 12 | tateyama
# Processing Record 22 of Set 12 | sibut
# Processing Record 23 of Set 12 | harstad
# Processing Record 24 of Set 12 | parapat
# Processing Record 25 of Set 12 | kapuskasing
# Processing Record 26 of Set 12 | atherton
# Processing Record 27 of Set 12 | bardai
# Processing Record 28 of Set 12 | hunkuyi
# Processing Record 29 of Set 12 | bengkulu
# Processing Record 30 of Set 12 | karabar
# Processing Record 31 of Set 12 | sauri
# Processing Record 32 of Set 12 | pong nam ron
# Processing Record 33 of Set 12 | yuzhno-kurilsk
# Processing Record 34 of Set 12 | clinton
# Processing Record 35 of Set 12 | port saint john's
# Processing Record 36 of Set 12 | agat village
# Processing Record 37 of Set 12 | jalalabad
# Processing Record 38 of Set 12 | nogliki
# Processing Record 39 of Set 12 | baghlan
# Processing Record 40 of Set 12 | ak-dovurak
# Processing Record 41 of Set 12 | sullivan
# Processing Record 42 of Set 12 | selfoss
# Processing Record 43 of Set 12 | teknaf
# Processing Record 44 of Set 12 | semnan
# Processing Record 45 of Set 12 | belyy yar
# Processing Record 46 of Set 12 | patnanungan
# Processing Record 47 of Set 12 | duki
# Processing Record 48 of Set 12 | stephenville
# Processing Record 49 of Set 12 | twardogora
# Processing Record 0 of Set 13 | banda aceh
# Processing Record 1 of Set 13 | puerto san jose
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0       grytviken -54.2811 -36.5092     -5.79        83          68
# 1      svetlograd  45.3353  42.8547     23.69        73         100
# 2           prado -17.3411 -39.2208     20.92        94           7
# 3  ribeira grande  38.5167 -28.7000     20.43        93          67
# 4    puerto ayora  -0.7393 -90.3518     25.31        92          17
#
#    Wind Speed Country        Date
# 0        5.39      GS  1688876033
# 1        1.79      RU  1688876276
# 2        3.19      BR  1688876276
# 3        0.89      PT  1688876276
# 4        2.68      EC  1688876276

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities_test.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities_test.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             grytviken -54.2811 -36.5092     -5.79        83          68
# 1            svetlograd  45.3353  42.8547     23.69        73         100
# 2                 prado -17.3411 -39.2208     20.92        94           7
# 3        ribeira grande  38.5167 -28.7000     20.43        93          67
# 4          puerto ayora  -0.7393 -90.3518     25.31        92          17
#
#          Wind Speed Country        Date
# City_ID
# 0              5.39      GS  1688876033
# 1              1.79      RU  1688876276
# 2              3.19      BR  1688876276
# 3              0.89      PT  1688876276
# 4              2.68      EC  1688876276

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = [data['Lat'] for data in city_data]
y_values = [data['Max Temp'] for data in city_data]
plt.scatter(x_values,y_values,edgecolor='black')


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Temperature (C)")
plt.title('City Latitude vs Max Temperature (date here)')
plt.grid(True)


# Save the figure
#plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = [data['Lat'] for data in city_data]
y_values = [data['Humidity'] for data in city_data]
plt.scatter(x_values,y_values,edgecolor='black')


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title('City Latitude vs Humidity  (date here)')
plt.grid(True)

# Save the figure
#plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = [data['Lat'] for data in city_data]
y_values = [data['Cloudiness'] for data in city_data]
plt.scatter(x_values,y_values,edgecolor='black')


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.title('City Latitude vs Cloudiness (date here)')
plt.grid(True)

# Save the figure
#plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = [data['Lat'] for data in city_data]
y_values = [data['Wind Speed'] for data in city_data]
plt.scatter(x_values,y_values,edgecolor='black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title('City Latitude vs Wind Speed (date here)')
plt.grid(True)

# Save the figure
#plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(x_values, y_values, x_label, y_label, hemisphere):
    # Perform linear regression
    slope, intercept, r_value, p_value, stderr = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    
    # Create scatter plot
    plt.scatter(x_values, y_values, edgecolor='black')
    plt.plot(x_values, regress_values, color='red')

    #Annotate the linear regression equation on the plot
    annotation = f"{equation}\nR-value = {round(r_value, 10)}"
    plt.annotate(equation, (0.1, 0.9), xycoords='axes fraction', fontsize=16, color='red')
    
    # Set labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(f"{hemisphere} Hemisphere: {y_label} vs. {x_label}")
   
    # Return the r-value
    return r_value

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            svetlograd  45.3353   42.8547     23.69        73         100
# 3        ribeira grande  38.5167  -28.7000     20.43        93          67
# 5         fort mcmurray  56.7268 -111.3810     24.73        53          20
# 9            labytnangi  66.6572   66.4183     13.30        81         100
# 10           fort bragg  35.1390  -79.0060     24.00        90           0
#
#          Wind Speed Country        Date
# City_ID
# 1              1.79      RU  1688876276
# 3              0.89      PT  1688876276
# 5              2.57      CA  1688876218
# 9              0.89      RU  1688875997
# 10             2.06      US  1688876278

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] <= 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           grytviken -54.2811  -36.5092     -5.79        83          68
# 2               prado -17.3411  -39.2208     20.92        94           7
# 4        puerto ayora  -0.7393  -90.3518     25.31        92          17
# 6           adamstown -25.0660 -130.1015     21.75        77          32
# 7            waitangi -43.9535 -176.5597      9.90        89          73
#
#          Wind Speed Country        Date
# City_ID
# 0              5.39      GS  1688876033
# 2              3.19      BR  1688876276
# 4              2.68      EC  1688876276
# 6              8.71      PN  1688876102
# 7              1.79      NZ  1688876277

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Max Temperature (°C)', 'Northern')

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: -0.6328967512386692

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Max Temperature (°C)', 'Southern')

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: 0.7667277095145604

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Humidity %', 'Northern')

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: -0.10583348565055642

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Humidity %', 'Southern')

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: 0.03652739814668395

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Cloudiness %', 'Northern')

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: -0.03557891299132248

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Cloudiness %', 'Southern')

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: -0.06619198862971962

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Wind Speed (m/s)', 'Northern')

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: -0.1450256000876606

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Wind Speed (m/s)', 'Southern')

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: -0.19763184412697263

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
