# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
#print(cities)
# Out:
# Number of cities in the list: 624

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lebu
# Processing Record 2 of Set 1 | bilibino
# Processing Record 3 of Set 1 | hirara
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | wayne
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | sechura
# Processing Record 8 of Set 1 | port-aux-francais
# Processing Record 9 of Set 1 | ilulissat
# Processing Record 10 of Set 1 | ola
# Processing Record 11 of Set 1 | ifakara
# Processing Record 12 of Set 1 | west island
# Processing Record 13 of Set 1 | san pedro pochutla
# Processing Record 14 of Set 1 | datong
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | udachny
# Processing Record 17 of Set 1 | brookings
# Processing Record 18 of Set 1 | flin flon
# Processing Record 19 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 20 of Set 1 | mweka
# Processing Record 21 of Set 1 | waitangi
# Processing Record 22 of Set 1 | mikuni
# Processing Record 23 of Set 1 | blackmans bay
# Processing Record 24 of Set 1 | grand falls-windsor
# Processing Record 25 of Set 1 | north side
# Processing Record 26 of Set 1 | rongelap
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | atafu village
# Processing Record 29 of Set 1 | olonkinbyen
# Processing Record 30 of Set 1 | namibe
# Processing Record 31 of Set 1 | isafjordur
# Processing Record 32 of Set 1 | raja
# Processing Record 33 of Set 1 | invercargill
# Processing Record 34 of Set 1 | bethel
# Processing Record 35 of Set 1 | souillac
# Processing Record 36 of Set 1 | margaret river
# Processing Record 37 of Set 1 | puerto natales
# Processing Record 38 of Set 1 | laojunmiao
# Processing Record 39 of Set 1 | kataragama
# City not found. Skipping...
# Processing Record 40 of Set 1 | talnakh
# Processing Record 41 of Set 1 | edinburgh of the seven seas
# Processing Record 42 of Set 1 | arevalo
# Processing Record 43 of Set 1 | papatowai
# Processing Record 44 of Set 1 | iskateley
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | vila velha
# Processing Record 47 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 48 of Set 1 | essaouira
# Processing Record 49 of Set 1 | palikir - national government center
# Processing Record 50 of Set 1 | tarauaca
# Processing Record 0 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | strezhevoy
# Processing Record 3 of Set 2 | adamstown
# Processing Record 4 of Set 2 | mount gambier
# Processing Record 5 of Set 2 | cromer
# Processing Record 6 of Set 2 | puerto deseado
# Processing Record 7 of Set 2 | st. john's
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | hawaiian paradise park
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | minas de marcona
# Processing Record 12 of Set 2 | badger
# Processing Record 13 of Set 2 | lata
# Processing Record 14 of Set 2 | road town
# Processing Record 15 of Set 2 | sur
# Processing Record 16 of Set 2 | anadyr
# Processing Record 17 of Set 2 | colonia
# Processing Record 18 of Set 2 | armenia
# Processing Record 19 of Set 2 | lorengau
# Processing Record 20 of Set 2 | ushuaia
# Processing Record 21 of Set 2 | priozersk
# Processing Record 22 of Set 2 | acapulco de juarez
# Processing Record 23 of Set 2 | nishinoomote
# Processing Record 24 of Set 2 | pontes e lacerda
# Processing Record 25 of Set 2 | knysna
# Processing Record 26 of Set 2 | luganville
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | port mathurin
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | whitehorse
# Processing Record 31 of Set 2 | vernon
# Processing Record 32 of Set 2 | anloga
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | salalah
# Processing Record 35 of Set 2 | tadine
# Processing Record 36 of Set 2 | hasaki
# Processing Record 37 of Set 2 | labrador city
# Processing Record 38 of Set 2 | nar'yan-mar
# Processing Record 39 of Set 2 | chibougamau
# Processing Record 40 of Set 2 | sultanah
# Processing Record 41 of Set 2 | uturoa
# Processing Record 42 of Set 2 | banff
# Processing Record 43 of Set 2 | constantia
# Processing Record 44 of Set 2 | mpika
# Processing Record 45 of Set 2 | mugia
# Processing Record 46 of Set 2 | polyarnyy
# Processing Record 47 of Set 2 | aksu
# Processing Record 48 of Set 2 | dien bien phu
# Processing Record 49 of Set 2 | trunovskoye
# Processing Record 0 of Set 3 | sinan
# Processing Record 1 of Set 3 | kodiak
# Processing Record 2 of Set 3 | toppenish
# Processing Record 3 of Set 3 | moussoro
# Processing Record 4 of Set 3 | neryungri
# Processing Record 5 of Set 3 | enewetak
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | utrik
# Processing Record 8 of Set 3 | hagere hiywet
# Processing Record 9 of Set 3 | khromtau
# Processing Record 10 of Set 3 | yangor
# City not found. Skipping...
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | antofagasta
# Processing Record 13 of Set 3 | touros
# Processing Record 14 of Set 3 | tamanrasset
# Processing Record 15 of Set 3 | kenai
# Processing Record 16 of Set 3 | cockburn town
# Processing Record 17 of Set 3 | contamana
# Processing Record 18 of Set 3 | ghat
# Processing Record 19 of Set 3 | remire-montjoly
# Processing Record 20 of Set 3 | port glaud
# City not found. Skipping...
# Processing Record 21 of Set 3 | tromso
# Processing Record 22 of Set 3 | oituz
# Processing Record 23 of Set 3 | gaspe
# Processing Record 24 of Set 3 | kokuy
# Processing Record 25 of Set 3 | saint-laurent-du-maroni
# Processing Record 26 of Set 3 | afaahiti
# Processing Record 27 of Set 3 | sira
# Processing Record 28 of Set 3 | lensk
# Processing Record 29 of Set 3 | haiku-pauwela
# Processing Record 30 of Set 3 | qasr-e qand
# City not found. Skipping...
# Processing Record 31 of Set 3 | saipan
# Processing Record 32 of Set 3 | margate
# Processing Record 33 of Set 3 | moroeni
# Processing Record 34 of Set 3 | curvelo
# Processing Record 35 of Set 3 | port lincoln
# Processing Record 36 of Set 3 | belmonte
# Processing Record 37 of Set 3 | tobi village
# City not found. Skipping...
# Processing Record 38 of Set 3 | thompson
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | puerto ayora
# Processing Record 41 of Set 3 | hermanus
# Processing Record 42 of Set 3 | sambava
# Processing Record 43 of Set 3 | saint-pierre-du-mont
# Processing Record 44 of Set 3 | brak
# Processing Record 45 of Set 3 | severo-yeniseyskiy
# Processing Record 46 of Set 3 | vila franca do campo
# Processing Record 47 of Set 3 | fale old settlement
# Processing Record 48 of Set 3 | wajir
# Processing Record 49 of Set 3 | pingzhuang
# Processing Record 0 of Set 4 | deqen
# Processing Record 1 of Set 4 | dona mencia
# Processing Record 2 of Set 4 | hazorasp
# Processing Record 3 of Set 4 | la palma
# Processing Record 4 of Set 4 | eloy
# Processing Record 5 of Set 4 | willowmore
# Processing Record 6 of Set 4 | buta
# Processing Record 7 of Set 4 | klyuchi
# Processing Record 8 of Set 4 | pauls valley
# Processing Record 9 of Set 4 | turpan
# Processing Record 10 of Set 4 | arteche
# Processing Record 11 of Set 4 | alice springs
# Processing Record 12 of Set 4 | nova sintra
# Processing Record 13 of Set 4 | le port
# Processing Record 14 of Set 4 | medina
# Processing Record 15 of Set 4 | charlotte
# Processing Record 16 of Set 4 | mahina
# Processing Record 17 of Set 4 | vilyuchinsk
# Processing Record 18 of Set 4 | bairnsdale
# Processing Record 19 of Set 4 | college
# Processing Record 20 of Set 4 | puerto carreno
# Processing Record 21 of Set 4 | emboscada
# Processing Record 22 of Set 4 | iqaluit
# Processing Record 23 of Set 4 | beneditinos
# Processing Record 24 of Set 4 | nkurenkuru
# City not found. Skipping...
# Processing Record 25 of Set 4 | magadan
# Processing Record 26 of Set 4 | fuyang
# Processing Record 27 of Set 4 | greymouth
# Processing Record 28 of Set 4 | dwarka
# Processing Record 29 of Set 4 | tura
# Processing Record 30 of Set 4 | crane
# Processing Record 31 of Set 4 | carnot
# Processing Record 32 of Set 4 | geraldton
# Processing Record 33 of Set 4 | lospalos
# Processing Record 34 of Set 4 | almenara
# Processing Record 35 of Set 4 | vorgashor
# Processing Record 36 of Set 4 | saint-philippe
# Processing Record 37 of Set 4 | hastings
# Processing Record 38 of Set 4 | kalkandere
# Processing Record 39 of Set 4 | wailua homesteads
# Processing Record 40 of Set 4 | teknaf
# Processing Record 41 of Set 4 | tazovsky
# Processing Record 42 of Set 4 | zavidovo
# Processing Record 43 of Set 4 | igarka
# Processing Record 44 of Set 4 | sao gabriel da cachoeira
# Processing Record 45 of Set 4 | arno
# Processing Record 46 of Set 4 | jamestown
# Processing Record 47 of Set 4 | xinyuan
# Processing Record 48 of Set 4 | qarauyl
# Processing Record 49 of Set 4 | visakhapatnam
# Processing Record 0 of Set 5 | kunming
# Processing Record 1 of Set 5 | santona
# Processing Record 2 of Set 5 | kruisfontein
# Processing Record 3 of Set 5 | kongsvinger
# Processing Record 4 of Set 5 | holualoa
# Processing Record 5 of Set 5 | znamenskoye
# Processing Record 6 of Set 5 | la passe
# Processing Record 7 of Set 5 | lagoa santa
# Processing Record 8 of Set 5 | 'ibri
# City not found. Skipping...
# Processing Record 9 of Set 5 | teterow
# Processing Record 10 of Set 5 | trindade
# Processing Record 11 of Set 5 | thunder bay
# Processing Record 12 of Set 5 | anaconda
# Processing Record 13 of Set 5 | yarmouth
# Processing Record 14 of Set 5 | bac lieu
# Processing Record 15 of Set 5 | meadow lakes
# Processing Record 16 of Set 5 | panacan
# Processing Record 17 of Set 5 | stanley
# Processing Record 18 of Set 5 | santiago de cao
# Processing Record 19 of Set 5 | el alto
# Processing Record 20 of Set 5 | sinabang
# Processing Record 21 of Set 5 | thames
# Processing Record 22 of Set 5 | taperoa
# Processing Record 23 of Set 5 | gamba
# Processing Record 24 of Set 5 | hamilton
# Processing Record 25 of Set 5 | sharkan
# Processing Record 26 of Set 5 | gadzhiyevo
# Processing Record 27 of Set 5 | tralee
# Processing Record 28 of Set 5 | oroqen zizhiqi
# Processing Record 29 of Set 5 | ellsworth
# Processing Record 30 of Set 5 | akureyri
# Processing Record 31 of Set 5 | awjilah
# Processing Record 32 of Set 5 | tabuk
# Processing Record 33 of Set 5 | yorkton
# Processing Record 34 of Set 5 | nyandoma
# Processing Record 35 of Set 5 | noyon
# Processing Record 36 of Set 5 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 37 of Set 5 | livingston
# Processing Record 38 of Set 5 | lokken
# City not found. Skipping...
# Processing Record 39 of Set 5 | yagry
# City not found. Skipping...
# Processing Record 40 of Set 5 | asau village
# City not found. Skipping...
# Processing Record 41 of Set 5 | paradera
# City not found. Skipping...
# Processing Record 42 of Set 5 | kolyvan'
# Processing Record 43 of Set 5 | ust'-ilimsk
# Processing Record 44 of Set 5 | okha
# Processing Record 45 of Set 5 | buenaventura
# Processing Record 46 of Set 5 | sukhobezvodnoye
# Processing Record 47 of Set 5 | argo
# Processing Record 48 of Set 5 | roberval
# Processing Record 49 of Set 5 | princeville
# Processing Record 0 of Set 6 | vadso
# Processing Record 1 of Set 6 | antalaha
# Processing Record 2 of Set 6 | kalabo
# Processing Record 3 of Set 6 | taulaga
# Processing Record 4 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 5 of Set 6 | papao
# Processing Record 6 of Set 6 | chiredzi
# Processing Record 7 of Set 6 | sarmiento
# Processing Record 8 of Set 6 | viedma
# Processing Record 9 of Set 6 | pangody
# Processing Record 10 of Set 6 | wenling
# Processing Record 11 of Set 6 | praia da vitoria
# Processing Record 12 of Set 6 | kyaikkami
# Processing Record 13 of Set 6 | maceio
# Processing Record 14 of Set 6 | luwuk
# Processing Record 15 of Set 6 | sanctuary point
# Processing Record 16 of Set 6 | talara
# Processing Record 17 of Set 6 | the pas
# Processing Record 18 of Set 6 | general acha
# Processing Record 19 of Set 6 | tsiombe
# Processing Record 20 of Set 6 | newman
# Processing Record 21 of Set 6 | iquique
# Processing Record 22 of Set 6 | nogliki
# Processing Record 23 of Set 6 | karachev
# Processing Record 24 of Set 6 | lerwick
# Processing Record 25 of Set 6 | qurayyat
# Processing Record 26 of Set 6 | ascension
# Processing Record 27 of Set 6 | pisco
# Processing Record 28 of Set 6 | flying fish cove
# Processing Record 29 of Set 6 | usogorsk
# Processing Record 30 of Set 6 | lethem
# Processing Record 31 of Set 6 | isangel
# Processing Record 32 of Set 6 | okhotsk
# Processing Record 33 of Set 6 | al bawiti
# Processing Record 34 of Set 6 | goundi
# Processing Record 35 of Set 6 | eirunepe
# Processing Record 36 of Set 6 | puerto armuelles
# Processing Record 37 of Set 6 | las matas de santa cruz
# Processing Record 38 of Set 6 | st. johns
# Processing Record 39 of Set 6 | tchintabaraden
# Processing Record 40 of Set 6 | qaqortoq
# Processing Record 41 of Set 6 | puerto lempira
# Processing Record 42 of Set 6 | arica
# Processing Record 43 of Set 6 | duyun
# Processing Record 44 of Set 6 | claveria
# Processing Record 45 of Set 6 | kapuskasing
# Processing Record 46 of Set 6 | la'ie
# Processing Record 47 of Set 6 | butiama
# Processing Record 48 of Set 6 | mallow
# Processing Record 49 of Set 6 | rosso
# Processing Record 0 of Set 7 | koulikoro
# Processing Record 1 of Set 7 | keflavik
# Processing Record 2 of Set 7 | sakata
# Processing Record 3 of Set 7 | chernyshevskiy
# Processing Record 4 of Set 7 | nouadhibou
# Processing Record 5 of Set 7 | lubang
# Processing Record 6 of Set 7 | jayapura
# Processing Record 7 of Set 7 | hithadhoo
# Processing Record 8 of Set 7 | saryozek
# Processing Record 9 of Set 7 | alofi
# Processing Record 10 of Set 7 | dolores
# Processing Record 11 of Set 7 | mili
# Processing Record 12 of Set 7 | ataq
# Processing Record 13 of Set 7 | toga village
# City not found. Skipping...
# Processing Record 14 of Set 7 | katabu
# Processing Record 15 of Set 7 | laguna
# Processing Record 16 of Set 7 | olgii
# City not found. Skipping...
# Processing Record 17 of Set 7 | griffith
# Processing Record 18 of Set 7 | cambria
# Processing Record 19 of Set 7 | saint-francois
# Processing Record 20 of Set 7 | ad dabbah
# Processing Record 21 of Set 7 | san antonio de pale
# Processing Record 22 of Set 7 | bucerias
# Processing Record 23 of Set 7 | el galpon
# Processing Record 24 of Set 7 | isle of lewis
# City not found. Skipping...
# Processing Record 25 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 26 of Set 7 | bojnurd
# Processing Record 27 of Set 7 | alvinopolis
# Processing Record 28 of Set 7 | concepcion
# Processing Record 29 of Set 7 | ikalamavony
# Processing Record 30 of Set 7 | calabozo
# Processing Record 31 of Set 7 | ilabaya
# Processing Record 32 of Set 7 | andergrove
# Processing Record 33 of Set 7 | ahau
# City not found. Skipping...
# Processing Record 34 of Set 7 | shindand
# Processing Record 35 of Set 7 | betio village
# Processing Record 36 of Set 7 | arba minch
# Processing Record 37 of Set 7 | shilovo
# Processing Record 38 of Set 7 | portland
# Processing Record 39 of Set 7 | sakassou
# Processing Record 40 of Set 7 | sitka
# Processing Record 41 of Set 7 | canutama
# Processing Record 42 of Set 7 | aasiaat
# Processing Record 43 of Set 7 | zahedan
# Processing Record 44 of Set 7 | kaa-khem
# Processing Record 45 of Set 7 | amos
# Processing Record 46 of Set 7 | antakotako
# City not found. Skipping...
# Processing Record 47 of Set 7 | buulobarde
# Processing Record 48 of Set 7 | las khorey
# Processing Record 49 of Set 7 | broken hill
# Processing Record 0 of Set 8 | rio grande
# Processing Record 1 of Set 8 | zeya
# Processing Record 2 of Set 8 | punta arenas
# Processing Record 3 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 4 of Set 8 | tolanaro
# Processing Record 5 of Set 8 | sisimiut
# Processing Record 6 of Set 8 | mabaruma
# Processing Record 7 of Set 8 | pop
# Processing Record 8 of Set 8 | aioun
# Processing Record 9 of Set 8 | daru
# Processing Record 10 of Set 8 | illizi
# Processing Record 11 of Set 8 | khandyga
# Processing Record 12 of Set 8 | sibolga
# Processing Record 13 of Set 8 | karukh
# Processing Record 14 of Set 8 | bonthe
# Processing Record 15 of Set 8 | petropavlovsk-kamchatsky
# Processing Record 16 of Set 8 | darnah
# Processing Record 17 of Set 8 | josenii bargaului
# Processing Record 18 of Set 8 | kerikeri
# Processing Record 19 of Set 8 | boa vista
# Processing Record 20 of Set 8 | fuglafjordur
# Processing Record 21 of Set 8 | kismayo
# Processing Record 22 of Set 8 | palangkaraya
# Processing Record 23 of Set 8 | nadi
# Processing Record 24 of Set 8 | jinchang
# Processing Record 25 of Set 8 | teloloapan
# Processing Record 26 of Set 8 | maragogi
# Processing Record 27 of Set 8 | chehalis
# Processing Record 28 of Set 8 | lompoc
# Processing Record 29 of Set 8 | villamontes
# Processing Record 30 of Set 8 | poronaysk
# Processing Record 31 of Set 8 | uthal
# Processing Record 32 of Set 8 | ephrata
# Processing Record 33 of Set 8 | phan thiet
# Processing Record 34 of Set 8 | lahad datu
# Processing Record 35 of Set 8 | huntingdon
# Processing Record 36 of Set 8 | dunedin
# Processing Record 37 of Set 8 | el granada
# Processing Record 38 of Set 8 | mournies
# Processing Record 39 of Set 8 | kapa'a
# Processing Record 40 of Set 8 | conception bay south
# Processing Record 41 of Set 8 | mossel bay
# Processing Record 42 of Set 8 | patong
# Processing Record 43 of Set 8 | el calafate
# Processing Record 44 of Set 8 | kokpekty
# Processing Record 45 of Set 8 | codrington
# Processing Record 46 of Set 8 | georgiyevka
# Processing Record 47 of Set 8 | maintirano
# Processing Record 48 of Set 8 | collie
# Processing Record 49 of Set 8 | fada
# Processing Record 0 of Set 9 | kidal
# Processing Record 1 of Set 9 | pacific grove
# Processing Record 2 of Set 9 | howard springs
# Processing Record 3 of Set 9 | westport
# Processing Record 4 of Set 9 | new norfolk
# Processing Record 5 of Set 9 | cabedelo
# Processing Record 6 of Set 9 | cidreira
# Processing Record 7 of Set 9 | chonchi
# Processing Record 8 of Set 9 | terrell
# Processing Record 9 of Set 9 | ust-nera
# Processing Record 10 of Set 9 | port-gentil
# Processing Record 11 of Set 9 | san juan de miraflores
# Processing Record 12 of Set 9 | tarawa
# Processing Record 13 of Set 9 | villa hernandarias
# Processing Record 14 of Set 9 | derzhavinsk
# Processing Record 15 of Set 9 | galliano
# Processing Record 16 of Set 9 | punta del este
# Processing Record 17 of Set 9 | lhokseumawe
# Processing Record 18 of Set 9 | miagao
# Processing Record 19 of Set 9 | lamu
# Processing Record 20 of Set 9 | pionerskiy
# Processing Record 21 of Set 9 | sao joao da barra
# Processing Record 22 of Set 9 | tomiya
# Processing Record 23 of Set 9 | birobidzhan
# Processing Record 24 of Set 9 | leava
# Processing Record 25 of Set 9 | borazjan
# Processing Record 26 of Set 9 | pampas
# Processing Record 27 of Set 9 | drayton valley
# Processing Record 28 of Set 9 | gisborne
# Processing Record 29 of Set 9 | lodwar
# Processing Record 30 of Set 9 | karratha
# Processing Record 31 of Set 9 | burang
# Processing Record 32 of Set 9 | ghanzi
# Processing Record 33 of Set 9 | corner brook
# Processing Record 34 of Set 9 | zav'yalovo
# Processing Record 35 of Set 9 | tabou
# Processing Record 36 of Set 9 | fisterra
# Processing Record 37 of Set 9 | wanning
# Processing Record 38 of Set 9 | castillos
# Processing Record 39 of Set 9 | kalampaka
# Processing Record 40 of Set 9 | abadeh
# Processing Record 41 of Set 9 | sao vicente
# Processing Record 42 of Set 9 | acarau
# Processing Record 43 of Set 9 | houlton
# Processing Record 44 of Set 9 | balikpapan
# Processing Record 45 of Set 9 | i-n-salah
# Processing Record 46 of Set 9 | zhoushan
# Processing Record 47 of Set 9 | antsiranana
# Processing Record 48 of Set 9 | tongouson
# Processing Record 49 of Set 9 | partur
# Processing Record 0 of Set 10 | kingscliff
# Processing Record 1 of Set 10 | baikonur
# Processing Record 2 of Set 10 | san luis
# Processing Record 3 of Set 10 | amga
# Processing Record 4 of Set 10 | sandnessjoen
# Processing Record 5 of Set 10 | lihue
# Processing Record 6 of Set 10 | adam
# Processing Record 7 of Set 10 | tengrela
# Processing Record 8 of Set 10 | celestun
# Processing Record 9 of Set 10 | bembereke
# Processing Record 10 of Set 10 | talne
# City not found. Skipping...
# Processing Record 11 of Set 10 | kousseri
# Processing Record 12 of Set 10 | merowe
# Processing Record 13 of Set 10 | troitsko-pechorsk
# Processing Record 14 of Set 10 | san miguel
# Processing Record 15 of Set 10 | long beach
# Processing Record 16 of Set 10 | krasnyy kut
# Processing Record 17 of Set 10 | troitskiy
# Processing Record 18 of Set 10 | yoichi
# Processing Record 19 of Set 10 | cadale
# Processing Record 20 of Set 10 | kupang
# Processing Record 21 of Set 10 | rikaze
# Processing Record 22 of Set 10 | bambari
# Processing Record 23 of Set 10 | kirensk
# Processing Record 24 of Set 10 | malvan
# Processing Record 25 of Set 10 | ostrow mazowiecka
# Processing Record 26 of Set 10 | santa ana
# Processing Record 27 of Set 10 | vera
# Processing Record 28 of Set 10 | egilsstadir
# Processing Record 29 of Set 10 | dosso
# Processing Record 30 of Set 10 | n'dalatando
# Processing Record 31 of Set 10 | cabo san lucas
# Processing Record 32 of Set 10 | hadibu
# Processing Record 33 of Set 10 | howrah
# Processing Record 34 of Set 10 | bereket
# Processing Record 35 of Set 10 | pitomaca
# Processing Record 36 of Set 10 | choibalsan
# Processing Record 37 of Set 10 | caluula
# Processing Record 38 of Set 10 | aykhal
# Processing Record 39 of Set 10 | nabire
# Processing Record 40 of Set 10 | breves
# Processing Record 41 of Set 10 | trucuk
# Processing Record 42 of Set 10 | ad-damazin
# Processing Record 43 of Set 10 | nema
# Processing Record 44 of Set 10 | marat
# Processing Record 45 of Set 10 | mlyniv
# Processing Record 46 of Set 10 | levin
# Processing Record 47 of Set 10 | skovorodino
# Processing Record 48 of Set 10 | bamboo flat
# Processing Record 49 of Set 10 | lazaro cardenas
# Processing Record 0 of Set 11 | toguchin
# Processing Record 1 of Set 11 | fort mcmurray
# Processing Record 2 of Set 11 | furth im wald
# Processing Record 3 of Set 11 | yanchep
# Processing Record 4 of Set 11 | ginir
# Processing Record 5 of Set 11 | caleta de carquin
# Processing Record 6 of Set 11 | ungsang-nodongjagu
# Processing Record 7 of Set 11 | borrazopolis
# Processing Record 8 of Set 11 | esikhaleni
# Processing Record 9 of Set 11 | as sulayyil
# Processing Record 10 of Set 11 | am djarass
# City not found. Skipping...
# Processing Record 11 of Set 11 | dudinka
# Processing Record 12 of Set 11 | la ronge
# Processing Record 13 of Set 11 | dalandzadgad
# Processing Record 14 of Set 11 | two rivers
# Processing Record 15 of Set 11 | kourou
# Processing Record 16 of Set 11 | yuzhno-kurilsk
# Processing Record 17 of Set 11 | kulhudhuffushi
# Processing Record 18 of Set 11 | gulf shores
# Processing Record 19 of Set 11 | paramagudi
# Processing Record 20 of Set 11 | ceres
# Processing Record 21 of Set 11 | kolobrzeg
# Processing Record 22 of Set 11 | brigantine
# Processing Record 23 of Set 11 | saldanha
# Processing Record 24 of Set 11 | langxiang
# Processing Record 25 of Set 11 | spassk
# Processing Record 26 of Set 11 | nuuk
# Processing Record 27 of Set 11 | takoradi
# Processing Record 28 of Set 11 | necochea
# Processing Record 29 of Set 11 | kunashak
# Processing Record 30 of Set 11 | shuangcheng
# Processing Record 31 of Set 11 | north las vegas
# Processing Record 32 of Set 11 | puerto san carlos
# City not found. Skipping...
# Processing Record 33 of Set 11 | salahonda
# Processing Record 34 of Set 11 | urengoy
# Processing Record 35 of Set 11 | happy valley-goose bay
# Processing Record 36 of Set 11 | turtas
# Processing Record 37 of Set 11 | houghton
# Processing Record 38 of Set 11 | selfoss
# Processing Record 39 of Set 11 | maun
# Processing Record 40 of Set 11 | torghay
# Processing Record 41 of Set 11 | puerto baquerizo moreno
# Processing Record 42 of Set 11 | nemuro
# Processing Record 43 of Set 11 | benguela
# Processing Record 44 of Set 11 | tutoia
# Processing Record 45 of Set 11 | hobyo
# Processing Record 46 of Set 11 | usinsk
# Processing Record 47 of Set 11 | tual
# Processing Record 48 of Set 11 | hinton
# Processing Record 49 of Set 11 | pocatello
# Processing Record 0 of Set 12 | cozumel
# Processing Record 1 of Set 12 | dara
# Processing Record 2 of Set 12 | ladario
# Processing Record 3 of Set 12 | karmala
# Processing Record 4 of Set 12 | fortuna
# Processing Record 5 of Set 12 | korsakov
# Processing Record 6 of Set 12 | sesheke
# Processing Record 7 of Set 12 | taos
# Processing Record 8 of Set 12 | manokwari
# Processing Record 9 of Set 12 | zhangye
# Processing Record 10 of Set 12 | camana
# Processing Record 11 of Set 12 | lubao
# Processing Record 12 of Set 12 | tocopilla
# Processing Record 13 of Set 12 | ovalle
# Processing Record 14 of Set 12 | isabela
# Processing Record 15 of Set 12 | kavaratti
# Processing Record 16 of Set 12 | richards bay
# Processing Record 17 of Set 12 | gueltat zemmour
# City not found. Skipping...
# Processing Record 18 of Set 12 | stawell
# Processing Record 19 of Set 12 | at taj
# Processing Record 20 of Set 12 | roslavl'
# Processing Record 21 of Set 12 | berezovyy
# Processing Record 22 of Set 12 | pont-l'abbe
# City not found. Skipping...
# Processing Record 23 of Set 12 | rauma
# Processing Record 24 of Set 12 | mar del plata
# Processing Record 25 of Set 12 | fort bragg
# Processing Record 26 of Set 12 | sao tome
# Processing Record 27 of Set 12 | altay
# Processing Record 28 of Set 12 | dolinsk
# Processing Record 29 of Set 12 | saurimo
# Processing Record 30 of Set 12 | dondo
# Processing Record 31 of Set 12 | galveston
# Processing Record 32 of Set 12 | arawa
# Processing Record 33 of Set 12 | kramators'k
# Processing Record 34 of Set 12 | matoury
# Processing Record 35 of Set 12 | kristiansund
# Processing Record 36 of Set 12 | apodi
# Processing Record 37 of Set 12 | socorro
# Processing Record 38 of Set 12 | titabar
# Processing Record 39 of Set 12 | balabac
# Processing Record 40 of Set 12 | sishilichengzi
# City not found. Skipping...
# Processing Record 41 of Set 12 | pathein
# Processing Record 42 of Set 12 | dzhalagash
# Processing Record 43 of Set 12 | soe
# Processing Record 44 of Set 12 | tuy hoa
# Processing Record 45 of Set 12 | hoxter
# City not found. Skipping...
# Processing Record 46 of Set 12 | port hedland
# Processing Record 47 of Set 12 | san patricio
# Processing Record 48 of Set 12 | umm kaddadah
# Processing Record 49 of Set 12 | ormara
# Processing Record 0 of Set 13 | kayes
# Processing Record 1 of Set 13 | fangshan
# Processing Record 2 of Set 13 | banda aceh
# Processing Record 3 of Set 13 | sompeta
# Processing Record 4 of Set 13 | keelung
# Processing Record 5 of Set 13 | kavalerovo
# Processing Record 6 of Set 13 | baruun-urt
# Processing Record 7 of Set 13 | pasuquin
# Processing Record 8 of Set 13 | san cristobal
# Processing Record 9 of Set 13 | m'sila
# Processing Record 10 of Set 13 | peniche
# Processing Record 11 of Set 13 | mancio lima
# Processing Record 12 of Set 13 | ngambe
# Processing Record 13 of Set 13 | neyriz
# Processing Record 14 of Set 13 | ancud
# Processing Record 15 of Set 13 | massaguet
# Processing Record 16 of Set 13 | kingston
# Processing Record 17 of Set 13 | taoudenni
# Processing Record 18 of Set 13 | beitbridge
# Processing Record 19 of Set 13 | bengkulu
# Processing Record 20 of Set 13 | horizon city
# Processing Record 21 of Set 13 | ta`u
# Processing Record 22 of Set 13 | weno
# Processing Record 23 of Set 13 | shirgaon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          594
# Lat           594
# Lng           594
# Max Temp      594
# Humidity      594
# Cloudiness    594
# Wind Speed    594
# Country       594
# Date          594
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       lebu -37.6167  -73.6500      8.55        72          90        4.45
# 1   bilibino  68.0546  166.4372     27.43        31          25        5.04
# 2     hirara  24.8000  125.2833     34.15        62          75        7.72
# 3  grytviken -54.2811  -36.5092     -3.75        72           2        3.30
# 4      wayne  42.2506  -83.2833     23.30        88         100        5.14
#
#   Country        Date
# 0      CL  1689397829
# 1      RU  1689397829
# 2      JP  1689397830
# 3      GS  1689397830
# 4      US  1689397830

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             lebu -37.6167  -73.6500      8.55        72          90
# 1         bilibino  68.0546  166.4372     27.43        31          25
# 2           hirara  24.8000  125.2833     34.15        62          75
# 3        grytviken -54.2811  -36.5092     -3.75        72           2
# 4            wayne  42.2506  -83.2833     23.30        88         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.45      CL  1689397829
# 1              5.04      RU  1689397829
# 2              7.72      JP  1689397830
# 3              3.30      GS  1689397830
# 4              5.14      US  1689397830

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = [data['Lat'] for data in city_data]
y_values = [data['Max Temp'] for data in city_data]
plt.scatter(x_values,y_values,edgecolor='black')


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title('City Latitude vs Max Temperature (2023-09-15)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = [data['Lat'] for data in city_data]
y_values = [data['Humidity'] for data in city_data]
plt.scatter(x_values,y_values,edgecolor='black')


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title('City Latitude vs Humidity (2023-09-15)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = [data['Lat'] for data in city_data]
y_values = [data['Cloudiness'] for data in city_data]
plt.scatter(x_values,y_values,edgecolor='black')


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.title('City Latitude vs Cloudiness (2023-09-15)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = [data['Lat'] for data in city_data]
y_values = [data['Wind Speed'] for data in city_data]
plt.scatter(x_values,y_values,edgecolor='black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title('City Latitude vs Wind Speed (2023-09-15)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(x_values, y_values, x_label, y_label, hemisphere, x_coord=0.1, y_coord=0.9):
    # Perform linear regression
    slope, intercept, r_value, p_value, stderr = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    
    # Create scatter plot
    plt.scatter(x_values, y_values, edgecolor='black')
    plt.plot(x_values, regress_values, color='red')

    #Annotate the linear regression equation on the plot
    plt.annotate(equation, (x_coord, y_coord), xycoords='axes fraction', fontsize=14, color='red')
    
    # Set labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(f"{hemisphere} Hemisphere: {y_label} vs. {x_label}")
   
    # Return the r-value
    return r_value

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1         bilibino  68.0546  166.4372     27.43        31          25
# 2           hirara  24.8000  125.2833     34.15        62          75
# 4            wayne  42.2506  -83.2833     23.30        88         100
# 8        ilulissat  69.2167  -51.1000      9.01        81         100
# 9              ola  59.5833  151.2833     21.75        74           9
#
#          Wind Speed Country        Date
# City_ID
# 1              5.04      RU  1689397829
# 2              7.72      JP  1689397830
# 4              5.14      US  1689397830
# 8              2.06      GL  1689397832
# 9              4.93      RU  1689397832

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] <= 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                     lebu -37.6167 -73.6500      8.55        72          90
# 3                grytviken -54.2811 -36.5092     -3.75        72           2
# 5              east london -33.0153  27.9116     17.44        38          94
# 6                  sechura  -5.5569 -80.8222     22.61        75          13
# 7        port-aux-francais -49.3500  70.2167      2.39        60          53
#
#          Wind Speed Country        Date
# City_ID
# 0              4.45      CL  1689397829
# 3              3.30      GS  1689397830
# 5              5.54      ZA  1689397830
# 6              5.76      PE  1689397831
# 7             16.50      TF  1689397831

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Max Temperature (°C)', 'Northern', x_coord=0.1, y_coord=0.05)

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: -0.6176597961099386

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Max Temperature (°C)', 'Southern')

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: 0.7858186511327542

# %% [markdown]
# **Discussion about the linear relationship:** There appears to be a noticeable correlation between the latitide and temperature in both the Northern and Southern hemisphere regression plots.  Latitudes closer to the equator (latitude of zero) display higher temperatures and as the latitude moves away from the equator the temperature decreases.  Note there could be other factors influencing temperature, such as height above sea level.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Humidity %', 'Northern', x_coord=0.6, y_coord=0.05)

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: -0.05250075371586771

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Humidity %', 'Southern', x_coord=0.1, y_coord=0.05)

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: 0.10527758673371394

# %% [markdown]
# **Discussion about the linear relationship:** The r values of -0.052 and -0.105 in the humidity vs latitude regression plots indicate a weak correlation between these 2 measurements.  The fact that both the Northern and Southern calculations are both negative also supports this lack of correlation.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Cloudiness %', 'Northern', x_coord=0.03, y_coord=0.5)

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: -0.00958592201423354

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Cloudiness %', 'Southern', x_coord=0.03, y_coord=0.25)

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: -0.10288221566534599

# %% [markdown]
# **Discussion about the linear relationship:** The r values of -0.009 and -0.102 in the cloudiness vs latitude regression plots indicate a weak correlation between these 2 measurements.  The fact that both the Northern and Southern calculations are both negative also supports this lack of correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Wind Speed (m/s)', 'Northern', x_coord=0.3, y_coord=0.9)

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: -0.10084280745169157

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

r_value=create_linear_regression_plot(x_values, y_values, 'Latitude', 'Wind Speed (m/s)', 'Southern')

print(f" The r_value is: {r_value}")

# Show the plot
plt.show()
# Out:
#  The r_value is: -0.012044128527820688

# %% [markdown]
# **Discussion about the linear relationship:** The r values of -0.100 and -0.012 in the cloudiness vs latitude regression plots indicate a weak correlation between these 2 measurements.  The fact that both the Northern and Southern calculations are both negative also supports this lack of correlation.
